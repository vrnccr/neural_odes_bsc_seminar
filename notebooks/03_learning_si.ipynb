# %% [markdown]
# # Learning a two-dimensional SI rule
#
# This notebook trains from two SI trajectories, then starts the learned rule at an initial condition that was not used for training.

# %%
import sys
sys.path.insert(0, '../src')
from neural_odes_seminar.plotting import setup
from neural_odes_seminar.run import experiment_4
setup()
experiment_4()

# %% [markdown]
# The new initial condition lies on the same line S+I=1 and between the training conditions. It is an interpolation example, not a general test of every possible state.
