# %% [markdown]
# # Learning a decay rate and a decay rule
#
# The first experiment learns one unknown coefficient. The second lets a small neural network represent the whole derivative rule.

# %%
import sys, torch
sys.path.insert(0, '../src')
from neural_odes_seminar.plotting import setup
from neural_odes_seminar.run import experiment_2, experiment_3
torch.manual_seed(7)
setup()
parameter_result = experiment_2()
neural_result = experiment_3()
parameter_result, neural_result

# %% [markdown]
# The derivatives are not training labels. They are plotted after training only to check whether the learned rule resembles the known decay rule.
