# %% [markdown]
# # Understanding exponential decay
#
# This notebook asks: how does a local derivative rule produce a curve?

# %%
import sys
sys.path.insert(0, '../src')
from neural_odes_seminar.plotting import setup
from neural_odes_seminar.run import experiment_1
setup()
experiment_1()

# %% [markdown]
# The generated plot is saved in ../report/figures/01_euler_decay.pdf. Compare the two step sizes with the exact solution.
